# %%
import pandas as pd
import numpy as np
# Out:
# Libraries loaded successfully

# %%
df = pd.read_csv("../data/raw/product_reviews.csv")

# %%
df.head()
df.shape
# Out:
# (10, 2)

# %%
# Out:
# sentiment
# positive    5
# negative    5
# Name: count, dtype: int64

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kriha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\kriha\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kriha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

text = "I absolutely loved this phone!!!"

print("Original Text:", text)

text = text.lower()
print("Lowercase:", text)

text = text.translate(str.maketrans('', '', string.punctuation))
print("No Punctuation:", text)

tokens = word_tokenize(text)
print("Tokens:", tokens)

stop_words = set(stopwords.words("english"))
filtered_words = [word for word in tokens if word not in stop_words]

print("After Stopword Removal:", filtered_words)
# Out:
# Original Text: I absolutely loved this phone!!!
# Lowercase: i absolutely loved this phone!!!
# No Punctuation: i absolutely loved this phone
# Tokens: ['i', 'absolutely', 'loved', 'this', 'phone']
# After Stopword Removal: ['absolutely', 'loved', 'phone']
